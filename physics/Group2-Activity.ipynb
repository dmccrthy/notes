# %% [markdown]
# # Group 2

# %% [markdown]
# # Activity 1

# %% [markdown]
# ## Problem 1: Checks
#
# A: Seems like Vicky Whitney had a doctors visit, and Bill Whitney bought a car. Someone probably died since theres a check to a mortuary. Also one for Circuit City which could be any number of things.
#
# B: W A Whithney may have health condition or something due to high medical bill. This family probably has kids since there spending money on summer camp, and sports supplies. Also formal wear so could be an event like a wedding?
#
# C: William Whitney and Vicky Whitney are probably married since there spending money on marriage counseling. They also have kids since spending more money at Kid-R Us. More medical expences here so its very likeoy someone has an illness.
#
# D: Seems like one of there kids is sick with all the medical bills and how they are now donating to childrens charities. Also K-Mart for some reason.
#
# E: Somewhat confident, as it seems like from the dates on the checks that over the years someone in there family, maybe one of there kids, got sick and died.
#
# F: No, unless we ask the family we would have no real way of confirming this.
#
# G: We worked through the avalaible information and connected it together to get an idea of this family and there life even though we don't know them.

# %% [markdown]
# ## Problem 2: Experiment
#
# We could take a string and use in to measure the circufurence around a circular object. With another peice of string we could record the diameter of the circle. We could estimate the value of Pi by seeing how many peices the diameter string would be needed to match the length of the circufurence.
#
# To improve the precision of this experiment we would need something precise to measure the length of the strings so we can accuretly measure there really small fractional part of pi.

# %% [markdown]
# ## Problem 3:
#
# A: $7 mi * 1760 yd$
#
# = 12320 yd
#
# B: $7 mi * 1760 yd * 3 ft$
#
# = $36960 ft$
#
# C: $7 mi * 1.61 km$
#
# = $11.27 km$
#
# D: $11.2 mg / 1000 mg$
#
# = $0.0112 g$
#
# E: $1.5 kg * 2.2 lb$
#
# = $3.3 lb$
#
# F: $340 km/h / 1.61 km$
#
# = $211.18 mi/h$
#
# G:
#
# 32,800 Krona = $3,438.65
#
# 100,000 Yuan = $13,880.60
#
# H: $60 bpm * 60 minutes * 24 hours * 365 days * 86 years$
#
# = ~$2.7 * 10^9$ Heart Beats

# %% [markdown]
# ## Problem 4:
#
# $2x - y = 5$
#
# $6x + 6y = 2y + 8$
#
# A: Substitution
#
# Find value of y
#
# $2x -y = 5$
#
# $y = 2x - 5$
#
# Substitute in other equation
#
# $6x + 6(2x-5) = 2(2x-5) + 8$
#
# $6x + 12x - 30 = 4x - 10 + 8$
#
# $14x = 28$
#
# $x = 2$
#
# Use X to solve for Y
#
# $2(2) - y = 5$
#
# $y = -1$
#
#
# B: Addition
#
# Multiply first equation by -4
#
# $4(2x-y) = 20$
#
# Add them together
#
# $8x -4y = 20$
#
# $6x + 4y = 8$
#
# $14x = 28$
#
# $x = 2$
#
# Solve for y
#
# $2(2) - y = 5$
#
# $y = -1$
#
# C: Yes they are both equal
#
# D: Below
#
# ---
#
# $3x + 2y = 3$
#
# $6x + 4y = 6$
#
# E: No
#
# There the same equation
#
# F:
#
# Only one line will show up since there the same equation.
#
#
# $ax + by = c$
#
# $dx + ey = f$
#
# ---
#
# G:
#
# $ax = c - by$
#
# $x = \frac{c}{a} - \frac{b}{a}y$
#
# Plug in x value
#
# $d(\frac{c}{a} - \frac{b}{a}y) + ey = f$
#
# $\frac{dc}{a} - \frac{db}{a}y + ey = f$
#
# $y(\frac{db}{a} + e) = f - \frac{dc}{a}$
#
# $y = \frac{f}{db/a + e} - \frac{dc}{db + ea}$
#
# H:
#
# $x = \frac{5}{2} - \frac{-1}{2} * -1$
#
# $x =\frac{4}{2}$
#
# $x = 2$
#
# Solve for y also
#
# $y(\frac{6}{2} + 4) = 8 - \frac{30}{2}$
#
# $y = -7 / 7$
#
# $y = -1$

# %%
# Plot for #4 part D

import matplotlib.pyplot as plt
import numpy as np

# setting the x - coordinates
x = np.arange(0, 6, 0.1)
# setting the corresponding y - coordinates
y1 = 2*x - 5
y2 = 2 - 1.5 * x

# Plot them
plt.plot(x, y1, 'r')
plt.plot(x, y2, 'b')
plt.show()

# %% [markdown]
# # Activity 2:

# %% [markdown]
# ## Problem 1:
#
# A:
#
# ![Screenshot from 2025-06-03 11-44-10.png](data:image/png;base64,...)
#
# B:
#
# His distance from the stump would be the hypotenuse of the triangle formed by his 200m east and 100m north.
#
# $100^2 + 200^2 = c^2$
#
# $50,000 = c^2$
#
# $c = \sqrt{50,000}$
#
# $c ≈ 223.606$
#
# C:
#
# $tan^{-1} (\frac{100}{200}) = \theta$
#
# $= 26.6$ degrees North of east

# %% [markdown]
# ## Problem 2:
#
# A:
#
# ![Screenshot from 2025-06-03 11-54-34.png](data:image/png;base64,...)
#
# B:
#
# $20 - 10 = 10$
#
# $10$ feet East

# %% [markdown]
# ## Problem 3:

# %% [markdown]
# A:
#
# ![Screenshot from 2025-06-03 11-58-37.png](data:image/png;base64,...)
#
# B:
#
# He is $21.3$ feet away
#
# C:
#
# We found the hight of the triangle which was 7.5 feet and the base which was 12.19 feet. Then added ten to 7.5 to get the total hight of the route and 12.19 was the total direction east.Then created a right triangle using these measurements and found the hypotenuse which was 21.3

# %% [markdown]
# ## Problem 4:
#
# A:
#
# We can use sin($\theta$) to find the A_y portion of the vector.
#
# $sin(\theta) = \frac{A_y}{\vec{A}}$
#
# $\vec{A} * sin(\theta) = A_y$
#
# We can do the same for cos($\theta$)
#
# $cos(\theta) = \frac{A_x}{\vec{A}}$
#
# $\vec{A} * cos(\theta) = A_x$
#
# B:
#
# We would just change wich component we use for sine and cosine.
#
# $cos(\phi) = \frac{A_y}{\vec{A}}$
#
# $\vec{A} * cos(\phi) = A_y$
#
# Repeat for sine aswell
#
# $sin(\phi) = \frac{A_x}{\vec{A}}$
#
# $\vec{A} * sin(\phi) = A_x$
#
# C:
#
# $\vec{V} = 250\hat{x} + 433\hat{y}$
#
# D:
#
# It just changes the sign.
#
# $\vec{V} = 250\hat{x} - 433\hat{y}$

# %% [markdown]
# ## Problem 6?
#
# ### *It seems like problem 5 is missing from the sheet.
#
# A:
#
# $\vec{A}$ is 30 feet due East
#
# $\vec{B}$ is 40 feet at 30° North of East
#
# $C_x = 30\hat{x} + 34.64\hat{x}$
#
# $C_y = 20\hat{y}$
#
# $\vec{C} = 64.64\hat{x} + 20\hat{y}$
#
# Then finish out triangle with pythagorean theorem.
#
# The Zombie would need to go 67.66 feet 72.80° South of West
#
# B:
#
# $\vec{A}$ is 450 mph 20° East of North
#
# $\vec{B}$ is 90 mph 40° South of East
#
# $C_x = 422\hat{y} + 62.94\hat{x}$
#
# $C_y = 153\hat{y} - 57.85\hat{y}$
#
# $\vec{C} = 484.94\hat{x} + 95.15\hat{y}$
#
# Finish out the triangle with pythagorean theorem.
#
# Relative to the ground the Airplane is moving 500.08 mph 10.97° North of East
#
# C:
#
# $\vec{A}$ is 8 meters due west
#
# $\vec{B}$ is 2 meters due east
#
# $\vec{C}$ is 6 meters 30° East of North
#
# $C_x = 13\hat{x}$
#
# $C_y = 5.9\hat{y}$
#
# $\vec{C} = 13\hat{x} + 5.9\hat{y}$
#
# Finish out rest of triangle
#
# They are 14 meters away from eachother.
#
# D:
#
# Cartman needs to shoot 68.24° South of West to hit Kenny.

# %% [markdown]
# # Activity 3

# %% [markdown]
# ## Problem 1:
#
# A:
#
# The slope of this function would represent its rate of change, which is just how much the function is changing over some range. If we had the actual function for this graph we could take its derivative to find the slope at any given point on the graph. Since this is a pretty basic graph though, we can just find the slope by looking at it.
#
# B:
#
# speed = $\frac{4-2}{3-2}$
#
# speed = $2$ meters per second
#
# C:
#
# He's not moving so its:
#
# $0$ meters per second
#
# D:
#
# speed = $3$ meters per second
#
# Note: I haven't written this as a negative value since I think this problem is asking for the magnitude only.
#
# E:
#
# For t = 3:
#
# velocity = $2\hat{x}$ m/s
#
# For t = 7:
#
# vecocity = $-3\hat{x}$ m/s
#
# F:
#
# He's 2 meter from where he started.
#
# G:
#
# No, as he walked 4 meters forward and then 6 meters back for a total of 10 meter, but only actually displaced 2.
#
# H:
#
# velocity = $\frac{0-2}{8-0}$
#
# velocity = $\frac{-1}{4}$

# %% [markdown]
# ## Problem 2:
#
# A:
#
# Below in python
#
# B:
#
# We can set them equal then solve for t:
#
# $3t + 4 = 2t^2 - 2$
#
# $0 = 2t^2 - 3t - 6$
#
# $t = 2.6$
#
#
# C:
#
# Stan is going faster initially since when you plug 0 into both equations his has the larger starting value.
#
# Stan = 4
#
# Kyle = -2
#
# D:
#
# Kyle as his function grows faster. We can tell by pluggin in 3 for both functions.
#
# Stan = 13
#
# Kyle = 16
#
# E:
#
# Stan is traveling at a constant velocity since his function is linear (to the power of 1).
#
# Kyle's function is quadratic so its going to grow quicker as the input gets larger.
#
# F:
#
# Kyle is the slowest when he first starts out as the input is going to be put to the power of 2. So at 0.5 seconds his equation looks like:
#
# $2(0.5 * 0.5) - 2$
#
# Which is small.

# %%
# Plot for #4 part D

import matplotlib.pyplot as plt
import numpy as np

# setting the x - coordinates
x = np.arange(0, 5, 0.1)
# setting the corresponding y - coordinates
y1 = 3*x + 4
y2 = 2*(x*x) - 2

# Plot them
plt.plot(x, y1, 'r')
plt.plot(x, y2, 'b')
plt.show()

# %% [markdown]
# ## Problem 3:
#
# A:
#
# No, its not constant since the line curves. This means the slope changes and isn't some linear value.
#
# B:
#
# velocity = $-10$ m/s
#
# C:
#
# It would be since we can can multiply the velocity by the time to find where it is. It could be innacurate if the balls downward velocity grows though so its not perfect.
#
# D:
#
# $x(t) = 20 -4.9t^2$
#
# $v'(t) = \lim_{Δt →0} \frac{x(t + Δt) - x(t)}{Δt}$
#
# $v'(t) = \lim_{Δt →0} \frac{20 - 4.9(t + Δt)^2 - 20 - 4.9(t)^2}{Δt}$
#
# $v'(t) = \lim_{Δt →0} \frac{4.9t^2 - 4.9(t^2 + 2tΔt + Δt^2)}{Δt}$
#
# $v'(t) = \lim_{Δt →0} -9.6t + 4.9Δt$
#
# $v'(t) = -9.6t$
#
# And thats the answer
#
# E:
#
# This is pretty similiar to the last one:
#
# $x(t) = A + Bt^n$
#
# $v'(t) = \lim_{Δt →0} \frac{x(t + Δt) - x(t)}{Δt}$
#
# $v'(t) = \lim_{Δt →0} \frac{A + B(t + Δt)^n - A + B(t)^n}{Δt}$
#
# $v'(t) = \lim_{Δt →0} \frac{Bt^n - B(t + Δt)^n}{Δt}$
#
# No matter what the n value is the $Bt^n$ will be cancelled out.
#
# Additionally the largest value will be something like $nBΔt^n$
#
# Below is are writing from our Scribble:
#
# ![0.png](data:image/png;base64,...)
#
# F:
#
# $v'(t) = \lim_{Δt →0} \frac{-4.9t^2 - -4.9(t + Δt)^2}{Δt}$
#
# $v'(t) = \lim_{Δt →0} -9.6t + 4.9Δt$
#
# $v'(t) = -9.6t$
#
# So yes its the same.
#
# G:
#
# $a(t) = \lim_{Δt → 0} \frac{v(t + Δt) - v(t)}{Δt}$
#
# $a(t) = \lim_{Δt → 0} \frac{-9.6(t + Δt) + 9.6t}{Δt}$
#
# $a(t) = \lim_{Δt → 0} -9.6$
#
# $a(t) = -9.6$
#
# And thats the acceleration.
#
# H:
#
# The acceleration is constant as its just a straight line with no t value.

# %% [markdown]
# ## Problem 4:
#
# A:
#
# ![1.png](data:image/png;base64,...)
#
# B:
#
# ![2.png](data:image/png;base64,...)
#
# C:
#
# ![3.png](data:image/png;base64,...)
#
# Units are meter per second.

# %% [markdown]
# Problem 5: Extra Credit
#
# How does area A of the circle depend on time?
#
# It increases proportionally to the amount of time passed
#
# What is a rate of change R of area?
#
# The rate of change of area is equal 2πr
#
# How is R related to the circumference of the circle and why?
#
# It is exactly the same formula, thereby they are proportional and grow at the same rate.

# %% [markdown]
# # Activity 4

# %% [markdown]
# ## Problem 1:
#
# A:
#
# It is Zero at:
#
# 1, 2, 3
#
# Its MOST postive at:
#
# 0.5, 2.5
#
# Its MOST negative at:
#
# 1.5, 3.5
#
# B:
#
# ![IMG_8248.jpeg](data:image/jpeg;base64,...)
#
# C:
#
# ![part_c.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Problem 2:
#
# $x(t) = t^2 + 7t + 8$
#
# The velocity function is just the derivative of the position.
#
# $v(t) = 2t + 7$
#
# We can do this again to get the acceleration.
#
# $a(t) = 2$

# %% [markdown]
# ## Problem 3:
#
# The acceleration is shown below:
#
# ![1.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem 4:
#
# A:
#
# From 0 to 0.1:
#
# $acceleration = 0$ m/s
#
# From 0.1 to 0.15:
#
# $acceleration = 16$ m/s
#
# From 0.15 to 0.3:
#
# $acceleration = -5.2$ m/s
#
# From 0.3 to 0,4:
#
# $acceleration = 0$
#
# B:
#
# The total cm moved can be found by finding the area under the curve. Assuming we know the function we could do this with an integral, but here we can just calculate it out since its a triangle.
#
# $0.2 * 0.8 * 0.5 = 0.08$
#
# So its ~0.08 cm moved

# %% [markdown]
# ## Problem 5:
#
# To find the distance between the two signs we need to find the displacement, or area under the velocity graph.
#
# The first step is to find the speed the car accelerates to in the first 6 seconds.
#
# $a(t) = 4$
#
# $v(t) = 4t$
#
# $v(6) = 24$ m/s
#
# After it gets to 24 m/s it coast for 2 seconds, then decelerates.
#
# $a(t) = -3$
#
# $v(t) = -3t$
#
# $v(8) = -24$ m/s
#
# So after 8 seconds it will reach 0. From here we can find the area under each section of the velocity graph and get the displacement (wich is the same as the distance between the signs).
#
# $24 * 6 * 0.5 = 72$ meters
#
# $24 * 2 = 48$ meters
#
# $8 * 24 * 0.5 = 96$ meters
#
# We can add these up to get our total.
#
# 216 meters between stop signs.

# %% [markdown]
# ## Problem 6: Extra Credit
#
# The Honda Wins.
#
# We can find how many seconds it takes by finding the position function for each of these functions:
#
# acceleration = $3.5 * t$
#
# acceleration = $3.0 * t$
#
# Since we want to see the position functions we can do 2 integrals for each function to get back to the position function:
#
# $\int 3.5t \ dx = \frac{3.5}{2}t^2 + C$
#
# $\int \frac{3.5}{2}t^2 \ dx = \frac{3.5}{6}t^3 + C$
#
# $p_a(t) = \frac{3.5}{6}t^3$
#
# This is the position function for the porsche. We can repeat for the other car.
#
# $\int 3t \ dx = \frac{3}{2}t^2 + C$
#
# $\int \frac{3}{2}t^2 \ dx = \frac{1}{2}t^3 + C$
#
# $p_b(x) = \frac{1}{2}t^3$
#
# From here we can plug in 400 meters for the position and find at what time each car reaches them.
#
# The Porsche:
#
# $\frac{3.5}{6}t^3 = 400$
#
# $t ≈ 8.81$ seconds
#
# The Honda:
#
# $\frac{1}{2}t^3 = 400$
#
# $t ≈ 9.28$ seconds
#
# The porsche would win, BUT we have to add the 1 second head start it gives the Honda.
#
# So really the porsche got a time of 9.81 seconds
#
# So the Honda wins by ~0.53 seconds

# %% [markdown]
# ## Problem 7: Extra Credit
#
# In this case our velocity goes from 0 to 150 km/h in 0.5 seconds. We want m/s^2 so we should change 150 km/h to 150,000 m/h. Then we do the same thing from hours to seconds, 41.66 m/s. This can be graphed by the function below:
#
# $v(t) = 41.66t$$
#
# If we take the derivative we get:
#
# $a(t) = 41.66$
#
# This means the air has a constant acceleration of 41.66 $m/s^2$

# %% [markdown]
# ## Problem 8: Extra Credit
#
# This problem makes more sense when we think about it as what distance does the driver need to be from another car to stop while going 60 mph. We are given the decellertion which we can use to make an equation.
#
# also 60 miles = 316,800 feet. Divid this by minutes, then hours and we get the speed in ft/s, which is 88 ft/s.
#
# $v(t) = -21t$
#
# $-21t = 88$
#
# $4.19$ seconds to decelerate. Add on a second for reaction time. Which is $5.19$ seconds.
#
# Multiply by 88 to find the safe distance.
#
# safe distance $= 456.72$ feet

# %% [markdown]
# # Activity 5

# %% [markdown]
# ## Problem 1:
#
# ### Section 2.1:
#
# For this part we just setup the ioLab and tested the wheel feature. Below is the resulting charts from moving it back and forth on the table:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Section 2.2:
#
# Sample Plot 1:
#
# 2: The position goes from 0.0 to 0.3 before stopping.
#
# 3: This makes since given the position is change linearly in the positive direction.
#
# 4: Nothing, its at rest. We can tell as its acceleration is 0, its velocity is 0, and its position remains constant where it is.
#
# 5: The position is moving backwards.
#
# 6: The velocity is pretty constant negatively which aligns with what we see on the position graph.
#
# 7: At these times someone was likely applying some force to the cart to move it. We can see at points like ~2.25 the cart massivelt drops acceleration which is likely cause the person stopped it.
#
# 8:
#
# During those times the acceleration is 0.
#
# 9:
#
# ![image.png](data:image/png;base64,...)
#
# 10:
#
# Down an incline it the acceleration downward would be the hypotenuse of the triangle formed by gravity and the slope.

# %% [markdown]
# Sample Plot 2:
#
# 2: During this time frame the velocity is decreasing linearally, which indicates there is a constant negative acceleration.
#
# 3: The acceleration is an almost constant negative value which makes sense as the the velocity was decreasing negatively every second.
#
# 4: At 1.75 the velocity goes from increasing to decreasing, which is reflected in the position graph as the position grows much slower before eventually decreasing.
#
# 5:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Problem 2:
#
# A:
#
# ![image.png](data:image/png;base64,...)
#
# In 30 minutes it travels 250 miles.
#
# B:
#
# Yes, you can find the displacement by multiplying the time by the velocity. This value is also the area under the curve as this graph just makes a rectangle.
#
# C:
#
# ![image.png](data:image/png;base64,...)
#
# Once again the displacement here is also the area under the velocity function. We could calculate it out since its just a triangle, but we could also use an integral:
#
# $\int_{0}^{30} v(t) \ dx$
#
# $\int_{0}^{30} 3t \ dt$
#
# $\frac{3}{2}t^2 |_{0}^{30}$
#
# $= 1350$ meters displaced
#
# D:
#
# ![image.png](data:image/png;base64,...)
#
# A here is just somke constant value:
#
# $a(t) = A$
#
# $v(t) = A*t$
#
# $\int_0^{T} A*t dt$
#
# $\frac{A}{2}t^2 |_0^T$
#
# $= \frac{A*T^2}{2}$ net displacement
#
# E:
#
# 19 meters
#
# F: v(t) = vᵢ + at
#
# G:
#
# ΔX = vᵢt + 1/2at
#
# H:
#
# No you cannot use that equation. The displacement is 17066.7 meters

# %% [markdown]
# ![image.png](data:image/png;base64,...)
