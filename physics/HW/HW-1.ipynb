# %% [markdown]
# # Homework 1:
#
# By: Dan McCarthy

# %% [markdown]
# ## Problem 1: Unit Conversion
#
# A:
#
# (i)
#
# $8in * 2.54cm = 20.32cm / 100 = 0.2032$ meters
#
# (ii)
#
# $500ft * 0.3048m = 152.4$ meters/min
#
# $152.4m / 60sec = 2.54$ meters/sec
#
# (iii)
#
# $60mph * 1.6093 km = 96.558$ km/h
#
# $96.558 * 1000 = 96,558$ meters/h$
#
# $96,558 / 60 = 1,609.3 / 60 = 26.82$ meters/second
#
# (iv)
#
# $860 \ ft^2 * 0.3048 \ m^2 = 262.128 \ m^2$
#
# B:
#
# $\frac{100m}{10.49 sec} = 9.532$ m/s
#
# $9.532 \ m/s * 60 = 571.973 \ m/min * 60 = 34,318.398$ meters/hour
#
# $34,318.398m * 3.28ft = 112564.345$ ft/h
#
# $112564.345ft / 5280ft = 21.319$ mph
#
# C:
#
# First we need to calculate the meters in a light year.
#
# $3 * 10^8 * 31,557,600 = 94,672.8 * 10^{11}$ meters per year
#
# $9,467.28 * 10^{12} * 4.2 = 39,762.576 * 10^{12}$ meters
#
# There are ~1,609.344 meters in a mile so we cann use that to find the miles in a light year.
#
# $(39,762.576 / 1609.344) * 10^{12} \approx 24.70 * 10^{12}$ miles

# %% [markdown]
# ## Problem 2: Vector Components
#
# For these problems we just need to solve the triangles using trig:
#
# (i)
#
# $A_x = 5*cos(30)$
#
# $A_x = \frac{5 \sqrt{3}}{2}$
#
# $A_y = 5*sin(30)$
#
# $A_y = 2.5$
#
# (ii)
#
# For this one the triangle has an angle of 60° (30 + 30):
#
# $A_x = 5*cos(60)$
#
# $A_x = 2.5$
#
# $A_y = 5*sin(60)$
#
# $A_y = \frac{5 \sqrt{3}}{2}$
#
# (iii)
#
# This time its 30° + Θ, which is some unkown value. We can tell Θ = 45° since its opposite to the 45° angle.
#
# $A_x = 5*cos(75)$
#
# $A_x ≈ 1.294$
#
# $A_y = 5*sin(75)$
#
# $A_y ≈ 4.829$

# %% [markdown]
# ## Problem 3: Graphs of Motion
#
# A:
#
# (i): Its rate of change is smallest at point D. (Since its negative)
#
# (ii): Its rate of change (slope/velocity) is greatest at point B.
#
# (iii): Its at rest at A, C, and E.
#
# B:
#
# (i): Its moving the fastest at point D. (this is when its velocity is the greatest)
#
# (ii): Its speeding up at point C. Its important to note this is asking for speed not velocity (so a negative change in velocity like at point C is still speeding up).
#
# (iii): Its turning around at point B. (this is where is velocity reaches 0 before going negative)
#
# C:
#
# (i): The speed of A is greater than B. A's speed is constant here while be is slowly getting faster. At this point though B's speed is very slow.
#
# (ii): They have roughly the same speed at t = 3. To tell exactly we would need the position function for both A and B. We woud need to find the point when the derivative of B is equal to A.

# %% [markdown]
# ## Problem 4: Derivatives
#
# $x(t) = t^3 - 6t^2 + 4$
#
# Velocity and acceleration are just the first and second derivative of the position function:
#
# $v(t) = \frac{d}{dx} (x(t))$
#
# $v(t) = 3t^2 - 12t$
#
# Repeat for acceleration:
#
# $a(t) = \frac{d}{dx} (v(t))$
#
# $a(t) = 6t - 12$
#
# To find $t_1$ and $t_2$, we need to find when the object is not moving, which is just the roots of $v(t)$
#
# $0 = 3t^2 - 12t$
#
# $t = \frac{12 \pm \sqrt{144 - 4(3)(0}}{6}$
#
# $t = 0$ and $t = 4$
#
# Now plug into position and acceleration function:
#
# $x(0) = 4$
#
# $a(0) = -12$
#
# Repeat for $t_2$
#
# $x(4) = -28$
#
# $a(4) = 0$
#
# So, when t = 0:
#
# Acceleration = -12 m/s
#
# Coordinate = (0, 4)
#
# And, when t = 4:
#
# Acceleration = 0 m/s
#
# Coordinates = (4, -28)

# %% [markdown]
# ## Problem 5: Acceleration
#
# A:
#
# Since the acceleration is a constant 2 m/s the velocity is just the integral of that (2t). We do have to add 10 as that is the starting value.
#
# $v(t) = 10 + 2t$
#
# We can take the integral again to get the position function.
#
# $x(t) = 10t + t^2$
#
# Now we just have to solve for 200m.
#
# $200 = 10t + t^2$
#
# 0 = t^2 + 10t - 200$
#
# $t = -10 \pm \sqrt{100 - 4(-200)}$
#
# $t = -10 \pm \sqrt{900}$
#
# $t = -10 \pm 30$
#
# $t = 20$ or $t = -40$
#
# Obviously time can't be negative here so our answer is t = 20 seconds.
#
# B:
#
# $A_a(t) = -7$
#
# $A_b(t) = -5$
#
# (a):
#
# Use integral to find velocity and position function.
#
# $v(t) = 30 + -7t$
#
# $x(t) = 30t + \frac{-7}{2}t^2$
#
# We know the car is stopped when the velocity is 0.
#
# $0 = 30 - 7t$
#
# $t = \frac{30}{7}$
#
# We can plug into the position fucntion to find our distance.
#
# $x(\frac{30}{7}) = 30 * \frac{30}{7} + \frac{-7}{2}*(\frac{30}{7})^2$
#
# $x = 128.571 - 64.285$
#
# $x = 64.286$ meters
#
# So there is 64.286 meters stopping distance on dry concrete.
#
# (b):
#
# This is mostly the same problem as before just with a slightly different acceleration function.
#
# $v(t) = 30 - 5t$
#
# $x(t) = 30t - \frac{5}{2}t^2$
#
# Find when velocity is 0 then plug into position.
#
# $0 = 30 - 5t$
#
# $t = 6$ seconds
#
# $x(6) = 180 - \frac{5}{2}*36$
#
# $x = 90$
#
# So there is 90 meters stopping distance on wet concrete.
