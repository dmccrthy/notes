# %% [markdown]
# # Homework 3:
#
# By: Dan McCarthy

# %% [markdown]
# ## Problem 1:
#
# ![1.JPG](data:image/jpeg;base64,...)
#
# Since T3 needs to balance out the force of T1 and T2, we know T3 has to be related in some way. In this case its the hypotenus of the triangle of the 2 vectors.
#
# $T_3 = \sqrt{80^2+50^2}$
#
# $T_3 \approx 94.34 \ N$
#
# **So the tension in the 3rd rope is ~94.34 Newtons.**
#
# To find the direction we need to find the angles with the triangle formed by the vectors.
#
# $\theta = arctan(80/50)$
#
# $\theta \approx 57.9°$
#
# **So the rope is 57.9 degress South of East.**

# %% [markdown]
# ## Problem 2:
#
# ![2.JPG](data:image/jpeg;base64,...)
#
# A:
#
# This first question is really just a matter of knowing the formula for Force (F = ma), and knowing how to determine the actual acceleration accounting for gravity.
#
# We start knowing the elevator is accelerating downward at 2.8 m/s^2, but we also need to accont for the force of gravity acting on the bag.
#
# $60N = m * (9.8-2.8)$
#
# $m \approx 8.57$
#
# **So the mass is ~8.57 kg.**
#
# B:
#
# **It still reads ~60 Newtons.** Even though the velocites different this is effectively the same question as when measuring force we only care about acceleration (F = ma).
#
# C:
#
# This one is much easier since the system isn't experiencing any force, but the bag as gravity.
#
# $F = 8.57 * 9.8$
#
# $F \approx 84$ Newtons
#
# **So the scale will read about 84 newtons.**
#
# D:
#
# **The spring scale would read 0 Newtons,** since everything is falling at the same acceleration so they aren't able to apply force to eachother.

# %% [markdown]
# ## Problem 3:
#
# ![3.JPG](data:image/jpeg;base64,...)
#
# For this problem we can start by looking at the forces. Since the sled is going across a straight path we want to focus on the horizontal component of the Thrust force.
#
# $F_{TX} = F_T * cos(20deg)$
#
# $F_{TY} = F_T * sin(20deg)$
#
# To find the net horizontal force we need to subtract the horizontal force and friction.
#
# $F_{fr} = \mu * F_N$
#
# Then find normal force.
#
# $F_N = F_TY + F_G$
#
# $F_N = F_T*sin(20deg) + 4900$
#
# Now we can put that together.
#
# $F_{fr} = 0.5 * F_T * sin(20deg) + 4900$
#
# $F_{net} =  F_T * cos(20deg) - 0.5(4900 + F_T * sin(20deg))$
#
# Now the horizontal acceleration is just net force divided by mass so we can rewrit it like this.
#
# $A =  \frac{F_T * cos(20deg) -(2450 * F_T * 0.5sin(20deg))}{500}$
#
# Additionally we know what the horizontal acceleration is, as we know total distance covered in a given time.
#
# $100 = \frac{a}{2} (8)^2$
#
# $a = \frac{100}{32} = 3.125$
#
# So now we plug in A and solve
#
# $3.125 =  \frac{F_T * cos(20deg) -(2450 + F_T * (1/2*sin(20deg)))}{500}$
#
# $1562.5 = F_T * 0.9396 -(2450 + F_T * 0.171)$
#
# $1562.5 + 2450 = F_T(0.9396 - 0.171)$
#
# $4012.5 = F_T(0.7686)$
#
# $F_T \approx 5220.53 \ N$
#
# **So the thruster thing is applying ~5220.53 Newtons of force at 20°s South of East.**

# %% [markdown]
# ## Problem 4:
#
# A:
#
# The total force on the blocks is just the force from m2 and gravity.
#
# $F_{m2} = 1 * 9.8 = 9.8 \ N$
#
# Since this force is acting on the whole system we need to divide it by the total mass of the blocks to get the acceleration.
#
# $A = 9.8 / 5 = 1.96 \ m/s^2$
#
# **So the hanging block accelerates downward at 1.96 m/s^2.**
#
# B:
#
# To find the tension in the rope we just need to use the acceleration of the system times m1's mass since it is being pulled by the rope (the rope is exerting tension).
#
# $F_T = 4 * 1.96  = 7.84 \ N$
#
# **So the rope has 7.84 Newtons of tension.**
#
# C:
#
# This is pretty similiar to what we've done before, just need to account for the friction force when finding the net force of the system.
#
# $F_{m2} = 9.8 \ N$
#
# $F_{m1} = \mu * F_N$
#
# Since we're given mu, we just need to find the normal force for m1.
#
# $F_N = 4 * 9.8 = 39.2 \ N$
#
# $F_{m1} = 0.10 * 39.2 = 3.92 \ N$
#
# Now that we know the force of friction, we can subtract it from the rest of the force.
#
# $F_{net} = 9.8 - 3.92 = 5.88 \ N$
#
# So acceleration is jus tthe force divided by total mass like before.
#
# $5.88 / 5 = 1.176 \ m/s^2$
#
# **So the acceleration here is 1.176 m/s^2.**
#
# Like before we just multiply the acceleration and mass of m1 to get tension.
#
# $F_T = 4 * 1.176 = 4.704 \ N$
#
# **So the tension is 4.704 Newtons.**

# %% [markdown]
# ## Problem 5:
#
# ![4.JPG](data:image/jpeg;base64,...)
#
# To start I think it would help to write out the forces acting on the book., especially since this problem is a little much.
#
# $F_b = F_T + m_b*9.8*sin(20deg) + \mu * F_N$
#
# $F_T = m_m * 9.8$
#
# $F_b = m_m*9.8 + m_b*9.8*sin(20deg) + \mu * m_b*9.8*cos(20dedg)$
#
# Now that thats all written out we next need to figure out the acceleration. Since we have this force, we can divide by the total mass of the system to find the acceleration.
#
# $a = \frac{m_m*9.8 + 9.8*sin(20deg) + \mu*9.8*cos(20deg)}{m_m+m_b}$
#
# With this equation for Acceleration its just matter of doing out the math and will be almost there.
#
# $a = \frac{4.9 + 9.8*sin(20deg) + 0.6*9.8*cos(20deg)}{1.5}$
#
# $a = \frac{4.9 + 3.351 + 5.525}{1.5}$
#
# $a = -9.184 \ m/s^2$
#
# *accel. is negative since its going down the slope*
#
# Now we just solve the velocity of this for 0.
#
# $0 = 3 - 9.184t$
#
# $t \approx 0.3266s$
#
# **So it take ~0.3266 seconds to reach a stop.**
